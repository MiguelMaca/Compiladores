# %%
graph TD
    subgraph main
        M1(Inicio main) --> M2[resultado = suma 3, 5]
        M2 --> M3[retornar 0]
        M3 --> M4(Fin main)
    end

    subgraph suma
        S1(Inicio_suma) --> S2[c = a + b]
        S2 --> S3[retornar c]
        S3 --> S4(Fin_suma)
    end
